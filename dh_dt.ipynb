# %% [markdown]
# ## Reading and cropping dh/dt data

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import seaborn as sns
import scipy.io as sio
import os
import rasterio as rio
from rasterio.transform import from_origin, from_bounds, Affine
from shapely.geometry import Point, Polygon, mapping
import geopandas as gpd
from fnmatch import fnmatch

# %%
# https://gis.stackexchange.com/questions/446462/crop-raster-with-shapefile
def cropRaster(r, shp, name, path):
    from rasterio.mask import mask
    
    with rio.open(r) as src:
        out_image, out_transform = mask(src, shp, crop = True, filled = True) # setting all pixels outside of the feature zone to zero
        out_meta = src.meta

    out_meta.update({"driver": "GTiff",
    "height": out_image.shape[1],
    "width": out_image.shape[2],
    "crs":'EPSG:3031',
    "nodata":-9999,
    "transform": out_transform})

    output_file = f'{path}{name}_cropped.tif'

    with rio.open(output_file, "w", **out_meta) as dest:
        dest.write(out_image)
        dest.close()
        
def writeNpToRaster(array, path, name, trans):
    r = rio.open(path + str(name) + '.tif', # save filepath for save
        'w', # 'write' mode
        driver = 'GTiff', # produces a .tif
        height = array.shape[0], # y len
        width = array.shape[1], # x len
        count = 1, # number of bands
        dtype = array.dtype, # get datatype from input array (float)
        crs = 'EPSG:3031', # polar crs
        transform = trans) # transform to projection of another rio DataReader object
    r.write(array,1)
    r.close()
    
def read_Resample(r, factor):
    with rio.open(r) as src:
        data = src.read(1, out_shape = (src.count,
                                    int(src.height * factor),
                                    int(src.width * factor)
                                    ),
                        resampling = Resampling.bilinear
                       )
        # scale image transform
        transform = src.transform * src.transform.scale(
            (src.width / data.shape[-1]),
            (src.height / data.shape[-2])
        )
    return [data, transform]

# %% [markdown]
# First, I will open the .nc file and open the respective datasets

# %%
os.chdir('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/altimetry')
filename ='bb0448974g_2_1.h5'
is_H = h5py.File(filename,'r')

# %%
alt = is_H['h_alt'] # get altimetry
firn = is_H['h_firn'] # get firn air
time = is_H['time'] # get time in month indexes
alt_uncert = is_H['uncert_alt'] # get altimetry uncertainty
firn_uncert = is_H['uncert_firn'] # get firn uncertainty
x = is_H['x'] # get x coordinate
y = is_H['y'] # get y coordinate

# %% [markdown]
# Next I get the year and season for each data point.

# %%
times = list(time[0]) # get all times
years = [int(x) for x in times]
yrFracs = [(x % 1) for x in times]
roundedYr = [round(x,2) for x in yrFracs]
seasons = ['DJF', 'MAM', 'JJA','SON']
hSeasons = []
yearSeasons = []

for i in range(len(roundedYr)):
        if roundedYr[i] == 0.16:
            hSeasons.append(seasons[0])
        elif roundedYr[i] == 0.41:
            hSeasons.append(seasons[1])
        elif roundedYr[i] == 0.66:
            hSeasons.append(seasons[2])
        else:
            hSeasons.append(seasons[3])
for i in range(len(years)):
    yrSeas = str(years[i]) + hSeasons[i]
    yearSeasons.append(yrSeas)

# %% [markdown]
# Next I write the dh data to raster and flip the orientation while doing (it's upside down)

# %%
# get the transform
transform = from_origin(np.min(is_H['x']),np.max(is_H['y']), 10000, 10000)

for i in range(len(alt)):
    
    print(f'Doing file {yearSeasons[i]}')
    
    alt_day = alt[i,:,:]/365
    
    alt_array = np.flipud(alt_day) # FLIP THE ALT DATA
    
    alt_path  = '/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/altimetry/dh/' # set output path
    
    alt_name = yearSeasons[i] + '_alt_corr' # set filename
    
    writeNpToRaster(alt_array, alt_path, alt_name, transform) # write to raster
# Out:
# Doing file 1992MAM
# Doing file 1992JJA
# Doing file 1992SON
# Doing file 1993DJF
# Doing file 1993MAM
# Doing file 1993JJA
# Doing file 1993SON
# Doing file 1994DJF
# Doing file 1994MAM
# Doing file 1994JJA
# Doing file 1994SON
# Doing file 1995DJF
# Doing file 1995MAM
# Doing file 1995JJA
# Doing file 1995SON
# Doing file 1996DJF
# Doing file 1996MAM
# Doing file 1996JJA
# Doing file 1996SON
# Doing file 1997DJF
# Doing file 1997MAM
# Doing file 1997JJA
# Doing file 1997SON
# Doing file 1998DJF
# Doing file 1998MAM
# Doing file 1998JJA
# Doing file 1998SON
# Doing file 1999DJF
# Doing file 1999MAM
# Doing file 1999JJA
# Doing file 1999SON
# Doing file 2000DJF
# Doing file 2000MAM
# Doing file 2000JJA
# Doing file 2000SON
# Doing file 2001DJF
# Doing file 2001MAM
# Doing file 2001JJA
# Doing file 2001SON
# Doing file 2002DJF
# Doing file 2002MAM
# Doing file 2002JJA
# Doing file 2002SON
# Doing file 2003DJF
# Doing file 2003MAM
# Doing file 2003JJA
# Doing file 2003SON
# Doing file 2004DJF
# Doing file 2004MAM
# Doing file 2004JJA
# Doing file 2004SON
# Doing file 2005DJF
# Doing file 2005MAM
# Doing file 2005JJA
# Doing file 2005SON
# Doing file 2006DJF
# Doing file 2006MAM
# Doing file 2006JJA
# Doing file 2006SON
# Doing file 2007DJF
# Doing file 2007MAM
# Doing file 2007JJA
# Doing file 2007SON
# Doing file 2008DJF
# Doing file 2008MAM
# Doing file 2008JJA
# Doing file 2008SON
# Doing file 2009DJF
# Doing file 2009MAM
# Doing file 2009JJA
# Doing file 2009SON
# Doing file 2010DJF
# Doing file 2010MAM
# Doing file 2010JJA
# Doing file 2010SON
# Doing file 2011DJF
# Doing file 2011MAM
# Doing file 2011JJA
# Doing file 2011SON
# Doing file 2012DJF
# Doing file 2012MAM
# Doing file 2012JJA
# Doing file 2012SON
# Doing file 2013DJF
# Doing file 2013MAM
# Doing file 2013JJA
# Doing file 2013SON
# Doing file 2014DJF
# Doing file 2014MAM
# Doing file 2014JJA
# Doing file 2014SON
# Doing file 2015DJF
# Doing file 2015MAM
# Doing file 2015JJA
# Doing file 2015SON
# Doing file 2016DJF
# Doing file 2016MAM
# Doing file 2016JJA
# Doing file 2016SON
# Doing file 2017DJF
# Doing file 2017MAM
# Doing file 2017JJA
# Doing file 2017SON
# Doing file 2018DJF
# Doing file 2018MAM
# Doing file 2018JJA
# Doing file 2018SON

# %% [markdown]
# Now I crop the data to the right extent. First I read in my George VI shapefile:

# %%
georgevi = gpd.read_file('/Users/louie.bell/Desktop/mphil/Essay (Practical) 3/data/SCAR_coastline_product/georgeVI_poly.shp')
geoms = []
for i in range(len(georgevi)):
    geom = georgevi.loc[i]['geometry']
    geoms.append(geom)

# %% [markdown]
# Then I crop with my cropRaster function.

# %%
# get alt directory
alt_dir = os.listdir('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/altimetry/dh')
alt_path = '/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/altimetry/dh/'
alt_files = [file for file in alt_dir if fnmatch(file, '*.tif')]

output_path = '/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/altimetry/dh/dh_crop/'

for i in range(len(alt_files)):
    
    print(f'Doing file {alt_files[i]}')
    
    dh = alt_path + alt_files[i] # get file path
    
    name, ext = os.path.splitext(alt_files[i]) # get correct filename
    
    cropRaster(dh, geoms, name, output_path) # crop raster
    print(f'Cropping raster as {name}')
# Out:
# Doing file 1992JJA_alt_corr.tif
# Cropping raster as 1992JJA_alt_corr
# Doing file 2006MAM_alt_corr.tif
# Cropping raster as 2006MAM_alt_corr
# Doing file 2018SON_alt_corr.tif
# Cropping raster as 2018SON_alt_corr
# Doing file 2003DJF_alt_corr.tif
# Cropping raster as 2003DJF_alt_corr
# Doing file 2012JJA_alt_corr.tif
# Cropping raster as 2012JJA_alt_corr
# Doing file 2001SON_alt_corr.tif
# Cropping raster as 2001SON_alt_corr
# Doing file 1998SON_alt_corr.tif
# Cropping raster as 1998SON_alt_corr
# Doing file 2015DJF_alt_corr.tif
# Cropping raster as 2015DJF_alt_corr
# Doing file 2010MAM_alt_corr.tif
# Cropping raster as 2010MAM_alt_corr
# Doing file 1997SON_alt_corr.tif
# Cropping raster as 1997SON_alt_corr
# Doing file 2009MAM_alt_corr.tif
# Cropping raster as 2009MAM_alt_corr
# Doing file 1995DJF_alt_corr.tif
# Cropping raster as 1995DJF_alt_corr
# Doing file 2004JJA_alt_corr.tif
# Cropping raster as 2004JJA_alt_corr
# Doing file 2017SON_alt_corr.tif
# Cropping raster as 2017SON_alt_corr
# Doing file 2010SON_alt_corr.tif
# Cropping raster as 2010SON_alt_corr
# Doing file 2003JJA_alt_corr.tif
# Cropping raster as 2003JJA_alt_corr
# Doing file 1997MAM_alt_corr.tif
# Cropping raster as 1997MAM_alt_corr
# Doing file 2017MAM_alt_corr.tif
# Cropping raster as 2017MAM_alt_corr
# Doing file 2012DJF_alt_corr.tif
# Cropping raster as 2012DJF_alt_corr
# Doing file 2009SON_alt_corr.tif
# Cropping raster as 2009SON_alt_corr
# Doing file 2018MAM_alt_corr.tif
# Cropping raster as 2018MAM_alt_corr
# Doing file 2006SON_alt_corr.tif
# Cropping raster as 2006SON_alt_corr
# Doing file 2015JJA_alt_corr.tif
# Cropping raster as 2015JJA_alt_corr
# Doing file 1998MAM_alt_corr.tif
# Cropping raster as 1998MAM_alt_corr
# Doing file 2004DJF_alt_corr.tif
# Cropping raster as 2004DJF_alt_corr
# Doing file 2001MAM_alt_corr.tif
# Cropping raster as 2001MAM_alt_corr
# Doing file 1995JJA_alt_corr.tif
# Cropping raster as 1995JJA_alt_corr
# Doing file 1993DJF_alt_corr.tif
# Cropping raster as 1993DJF_alt_corr
# Doing file 2011SON_alt_corr.tif
# Cropping raster as 2011SON_alt_corr
# Doing file 1996MAM_alt_corr.tif
# Cropping raster as 1996MAM_alt_corr
# Doing file 2002JJA_alt_corr.tif
# Cropping raster as 2002JJA_alt_corr
# Doing file 2013DJF_alt_corr.tif
# Cropping raster as 2013DJF_alt_corr
# Doing file 2008SON_alt_corr.tif
# Cropping raster as 2008SON_alt_corr
# Doing file 2016MAM_alt_corr.tif
# Cropping raster as 2016MAM_alt_corr
# Doing file 2007SON_alt_corr.tif
# Cropping raster as 2007SON_alt_corr
# Doing file 2014JJA_alt_corr.tif
# Cropping raster as 2014JJA_alt_corr
# Doing file 1994JJA_alt_corr.tif
# Cropping raster as 1994JJA_alt_corr
# Doing file 2000MAM_alt_corr.tif
# Cropping raster as 2000MAM_alt_corr
# Doing file 1999MAM_alt_corr.tif
# Cropping raster as 1999MAM_alt_corr
# Doing file 2005DJF_alt_corr.tif
# Cropping raster as 2005DJF_alt_corr
# Doing file 2002DJF_alt_corr.tif
# Cropping raster as 2002DJF_alt_corr
# Doing file 2007MAM_alt_corr.tif
# Cropping raster as 2007MAM_alt_corr
# Doing file 1993JJA_alt_corr.tif
# Cropping raster as 1993JJA_alt_corr
# Doing file 1999SON_alt_corr.tif
# Cropping raster as 1999SON_alt_corr
# Doing file 2013JJA_alt_corr.tif
# Cropping raster as 2013JJA_alt_corr
# Doing file 2000SON_alt_corr.tif
# Cropping raster as 2000SON_alt_corr
# Doing file 2011MAM_alt_corr.tif
# Cropping raster as 2011MAM_alt_corr
# Doing file 1996SON_alt_corr.tif
# Cropping raster as 1996SON_alt_corr
# Doing file 2014DJF_alt_corr.tif
# Cropping raster as 2014DJF_alt_corr
# Doing file 2005JJA_alt_corr.tif
# Cropping raster as 2005JJA_alt_corr
# Doing file 2016SON_alt_corr.tif
# Cropping raster as 2016SON_alt_corr
# Doing file 2008MAM_alt_corr.tif
# Cropping raster as 2008MAM_alt_corr
# Doing file 1994DJF_alt_corr.tif
# Cropping raster as 1994DJF_alt_corr
# Doing file 2011DJF_alt_corr.tif
# Cropping raster as 2011DJF_alt_corr
# Doing file 1993SON_alt_corr.tif
# Cropping raster as 1993SON_alt_corr
# Doing file 2014MAM_alt_corr.tif
# Cropping raster as 2014MAM_alt_corr
# Doing file 1999JJA_alt_corr.tif
# Cropping raster as 1999JJA_alt_corr
# Doing file 2013SON_alt_corr.tif
# Cropping raster as 2013SON_alt_corr
# Doing file 1994MAM_alt_corr.tif
# Cropping raster as 1994MAM_alt_corr
# Doing file 2000JJA_alt_corr.tif
# Cropping raster as 2000JJA_alt_corr
# Doing file 2008DJF_alt_corr.tif
# Cropping raster as 2008DJF_alt_corr
# Doing file 1996JJA_alt_corr.tif
# Cropping raster as 1996JJA_alt_corr
# Doing file 2002MAM_alt_corr.tif
# Cropping raster as 2002MAM_alt_corr
# Doing file 2007DJF_alt_corr.tif
# Cropping raster as 2007DJF_alt_corr
# Doing file 2005SON_alt_corr.tif
# Cropping raster as 2005SON_alt_corr
# Doing file 2016JJA_alt_corr.tif
# Cropping raster as 2016JJA_alt_corr
# Doing file 2011JJA_alt_corr.tif
# Cropping raster as 2011JJA_alt_corr
# Doing file 2002SON_alt_corr.tif
# Cropping raster as 2002SON_alt_corr
# Doing file 2008JJA_alt_corr.tif
# Cropping raster as 2008JJA_alt_corr
# Doing file 2000DJF_alt_corr.tif
# Cropping raster as 2000DJF_alt_corr
# Doing file 2005MAM_alt_corr.tif
# Cropping raster as 2005MAM_alt_corr
# Doing file 1999DJF_alt_corr.tif
# Cropping raster as 1999DJF_alt_corr
# Doing file 2007JJA_alt_corr.tif
# Cropping raster as 2007JJA_alt_corr
# Doing file 1993MAM_alt_corr.tif
# Cropping raster as 1993MAM_alt_corr
# Doing file 2014SON_alt_corr.tif
# Cropping raster as 2014SON_alt_corr
# Doing file 1996DJF_alt_corr.tif
# Cropping raster as 1996DJF_alt_corr
# Doing file 2013MAM_alt_corr.tif
# Cropping raster as 2013MAM_alt_corr
# Doing file 1994SON_alt_corr.tif
# Cropping raster as 1994SON_alt_corr
# Doing file 2016DJF_alt_corr.tif
# Cropping raster as 2016DJF_alt_corr
# Doing file 2010JJA_alt_corr.tif
# Cropping raster as 2010JJA_alt_corr
# Doing file 2018DJF_alt_corr.tif
# Cropping raster as 2018DJF_alt_corr
# Doing file 2003SON_alt_corr.tif
# Cropping raster as 2003SON_alt_corr
# Doing file 2004MAM_alt_corr.tif
# Cropping raster as 2004MAM_alt_corr
# Doing file 1998DJF_alt_corr.tif
# Cropping raster as 1998DJF_alt_corr
# Doing file 2009JJA_alt_corr.tif
# Cropping raster as 2009JJA_alt_corr
# Doing file 2001DJF_alt_corr.tif
# Cropping raster as 2001DJF_alt_corr
# Doing file 1997DJF_alt_corr.tif
# Cropping raster as 1997DJF_alt_corr
# Doing file 1992MAM_alt_corr.tif
# Cropping raster as 1992MAM_alt_corr
# Doing file 2006JJA_alt_corr.tif
# Cropping raster as 2006JJA_alt_corr
# Doing file 2015SON_alt_corr.tif
# Cropping raster as 2015SON_alt_corr
# Doing file 2017DJF_alt_corr.tif
# Cropping raster as 2017DJF_alt_corr
# Doing file 2012MAM_alt_corr.tif
# Cropping raster as 2012MAM_alt_corr
# Doing file 1995SON_alt_corr.tif
# Cropping raster as 1995SON_alt_corr
# Doing file 1992SON_alt_corr.tif
# Cropping raster as 1992SON_alt_corr
# Doing file 2015MAM_alt_corr.tif
# Cropping raster as 2015MAM_alt_corr
# Doing file 2018JJA_alt_corr.tif
# Cropping raster as 2018JJA_alt_corr
# Doing file 2010DJF_alt_corr.tif
# Cropping raster as 2010DJF_alt_corr
# Doing file 2012SON_alt_corr.tif
# Cropping raster as 2012SON_alt_corr
# Doing file 2001JJA_alt_corr.tif
# Cropping raster as 2001JJA_alt_corr
# Doing file 1995MAM_alt_corr.tif
# Cropping raster as 1995MAM_alt_corr
# Doing file 2009DJF_alt_corr.tif
# Cropping raster as 2009DJF_alt_corr
# Doing file 1998JJA_alt_corr.tif
# Cropping raster as 1998JJA_alt_corr
# Doing file 2006DJF_alt_corr.tif
# Cropping raster as 2006DJF_alt_corr
# Doing file 2003MAM_alt_corr.tif
# Cropping raster as 2003MAM_alt_corr
# Doing file 1997JJA_alt_corr.tif
# Cropping raster as 1997JJA_alt_corr
# Doing file 2004SON_alt_corr.tif
# Cropping raster as 2004SON_alt_corr
# Doing file 2017JJA_alt_corr.tif
# Cropping raster as 2017JJA_alt_corr
