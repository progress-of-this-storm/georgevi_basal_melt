# %% [markdown]
# I need to work out why I'm getting the opposite values than what I expect for the data. This must be to do with something related to the height change, as it's the main control on the positive or negative sign of the melt.

# %%
import numpy as np
import rasterio as rio
import matplotlib.pyplot as plt
import geopandas as gpd
from rasterio.plot import show
import matplotlib

# %%
# read in raw anomaly data
MAM2016 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2016MAM.tif')
JJA2016 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2016JJA.tif')
SON2016 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2016SON.tif')
DJF2017 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2017DJF.tif')
MAM2017 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2017MAM.tif')
JJA2017 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2017JJA.tif')
SON2017 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2017SON.tif')
DJF2018 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2018DJF.tif')
MAM2018 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2018MAM.tif')
JJA2018 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2018JJA.tif')
SON2018 = rio.open('/Users/louie.bell/Cambridge/mphil/Essay (Practical) 3/data/basal melt/thickness/thickness_raw/2018SON.tif')

# %%
altDJF2016 = DJF2016.read(1)
altMAM2016 = MAM2016.read(1)
altJJA2016 = JJA2016.read(1)
altSON2016 = SON2016.read(1)
altDJF2017 = DJF2017.read(1)
altMAM2017 = MAM2017.read(1)
altJJA2017 = JJA2017.read(1)
altSON2017 = SON2017.read(1)
altDJF2018 = DJF2018.read(1)
altMAM2018 = MAM2018.read(1)
altJJA2018 = JJA2018.read(1)
altSON2018 = SON2018.read(1)

# %%
fig,ax=plt.subplots()
plt.imshow(altMAM2016)
hid = ax.imshow(altMAM2016)
plt.colorbar(hid,ax=ax)

# %%
fig,ax=plt.subplots()
plt.imshow(altJJA2016)
hid = ax.imshow(altJJA2016)
plt.colorbar(hid,ax=ax)
